# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np
# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
pwd
# Out:
# 'C:\\Users\\Ruth Falomir\\Documents\\DOCUMENTS\\ITESM\\Module_6\\World_Weather_Analysis\\Weather_Database\\Vacation_Search'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 583A-ECD9
#
#  Directory of C:\Users\Ruth Falomir\Documents\DOCUMENTS\ITESM\Module_6\World_Weather_Analysis\Weather_Database\Vacation_Search
#
# 10/25/2021  11:02 PM    <DIR>          .
# 10/25/2021  11:02 PM    <DIR>          ..
# 10/24/2021  10:08 PM    <DIR>          .ipynb_checkpoints
# 10/25/2021  07:11 PM    <DIR>          __pycache__
# 10/20/2021  09:28 PM                47 config.py
# 10/24/2021  06:17 PM                52 config2.py
# 10/25/2021  11:02 PM            54,454 Vacation_Search.ipynb
# 10/24/2021  10:32 PM            44,044 WeatherPy_Database.csv
# 10/25/2021  07:15 PM            14,106 WeatherPy_vacation.csv
#                5 File(s)        112,703 bytes
#                4 Dir(s)  430,341,734,400 bytes free

# %%
cd ..
# Out:
# C:\Users\Ruth Falomir\Documents\DOCUMENTS\ITESM\Module_6\World_Weather_Analysis\Weather_Database

# %%
cd Vacation_Search
# Out:
# C:\Users\Ruth Falomir\Documents\DOCUMENTS\ITESM\Module_6\World_Weather_Analysis\Weather_Database\Vacation_Search

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("WeatherPy_Database.csv")
city_data_df.head()
# Out:
#    City_ID            City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0  Severo-Kurilsk      RU  50.6789  156.1250     39.97        64
# 1        1    Puerto Ayora      EC  -0.7393  -90.3518     68.56        94
# 2        2    Port Moresby      PG  -9.4431  147.1797     89.02        70
# 3        3           Airai      TL  -8.9266  125.4092     80.55        38
# 4        4          Shache      CN  38.4167   77.2406     50.49        32
#
#    Cloudiness  Wind Speed Current Description
# 0          95       14.81     overcast clouds
# 1          95        3.00     overcast clouds
# 2          75       16.11                haze
# 3          94        2.33     overcast clouds
# 4         100        3.02     overcast clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 70
# What is the maximum temperature you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country      Lat       Lng  Max Temp  Humidity  \
# 2         2    Port Moresby      PG  -9.4431  147.1797     89.02        70
# 3         3           Airai      TL  -8.9266  125.4092     80.55        38
# 8         8     Grand Gaube      MU -20.0064   57.6608     76.37        67
# 10       10  Nisia Floresta      BR  -6.0911  -35.2086     79.61        82
# 13       13          Muriae      BR -21.1306  -42.3664     71.67        92
# 14       14        Bilaspur      IN  22.0833   82.1500     74.44        58
# 16       16         Rikitea      PF -23.1203 -134.9692     74.68        78
# 18       18          Avarua      CK -21.2078 -159.7750     77.05        57
# 19       19         Malakal      SS   9.5334   31.6605     74.62        51
# 23       23       Carnarvon      AU -24.8667  113.6333     75.27        53
#
#     Cloudiness  Wind Speed Current Description
# 2           75       16.11                haze
# 3           94        2.33     overcast clouds
# 8           78        8.01       broken clouds
# 10          76        7.00       broken clouds
# 13          87        3.74     overcast clouds
# 14           1        2.84           clear sky
# 16          46       16.37    scattered clouds
# 18          75       11.50       broken clouds
# 19          70        0.65       broken clouds
# 23          40       14.97    scattered clouds

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                284
# City                   284
# Country                283
# Lat                    284
# Lng                    284
# Max Temp               284
# Humidity               284
# Cloudiness             284
# Wind Speed             284
# Current Description    284
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.dropna()
clean_df.count()
# Out:
# City_ID                283
# City                   283
# Country                283
# Lat                    283
# Lng                    283
# Max Temp               283
# Humidity               283
# Cloudiness             283
# Wind Speed             283
# Current Description    283
# dtype: int64

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp Current Description      Lat       Lng  \
# 2     Port Moresby      PG     89.02                haze  -9.4431  147.1797
# 3            Airai      TL     80.55     overcast clouds  -8.9266  125.4092
# 8      Grand Gaube      MU     76.37       broken clouds -20.0064   57.6608
# 10  Nisia Floresta      BR     79.61       broken clouds  -6.0911  -35.2086
# 13          Muriae      BR     71.67     overcast clouds -21.1306  -42.3664
# 14        Bilaspur      IN     74.44           clear sky  22.0833   82.1500
# 16         Rikitea      PF     74.68    scattered clouds -23.1203 -134.9692
# 18          Avarua      CK     77.05       broken clouds -21.2078 -159.7750
# 19         Malakal      SS     74.62       broken clouds   9.5334   31.6605
# 23       Carnarvon      AU     75.27    scattered clouds -24.8667  113.6333
#
#    Hotel Name
# 2
# 3
# 8
# 10
# 13
# 14
# 16
# 18
# 19
# 23

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    params["location"] = f"{lat},{lng}"

    # 6e. Make request and retrieve the JSON data from the search. 
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    hotels = requests.get(base_url, params=params).json()
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_df["Hotel Name"].replace("", np.nan, inplace=True)
hotel_df.dropna(subset=["Hotel Name"], inplace=True)
hotel_df.head(50)
# Out:
#                City Country  Max Temp      Current Description      Lat  \
# 2      Port Moresby      PG     89.02                     haze  -9.4431
# 3             Airai      TL     80.55          overcast clouds  -8.9266
# 8       Grand Gaube      MU     76.37            broken clouds -20.0064
# 10   Nisia Floresta      BR     79.61            broken clouds  -6.0911
# 13           Muriae      BR     71.67          overcast clouds -21.1306
# 14         Bilaspur      IN     74.44                clear sky  22.0833
# 16          Rikitea      PF     74.68         scattered clouds -23.1203
# 18           Avarua      CK     77.05            broken clouds -21.2078
# 19          Malakal      SS     74.62            broken clouds   9.5334
# 23        Carnarvon      AU     75.27         scattered clouds -24.8667
# 26           Faanui      PF     76.62               light rain -16.4833
# 27     San Patricio      US     80.89                clear sky  28.0170
# 31          Bubaque      GW     82.15          overcast clouds  11.2833
# 33         Souillac      MU     76.35         scattered clouds -20.5167
# 35     Saint-Joseph      RE     71.98         scattered clouds -21.3667
# 40             Hilo      US     76.73               light rain  19.7297
# 46       Sungairaya      ID     88.03          overcast clouds   0.7000
# 53         Cabedelo      BR     79.47          overcast clouds  -6.9811
# 59           Trelew      AR     70.07          overcast clouds -43.2490
# 60   Saint-Philippe      RE     73.22         scattered clouds -21.3585
# 61           Magadi      IN     73.74          overcast clouds  12.9667
# 63         Pochutla      MX     78.82          overcast clouds  15.7432
# 67            Vaini      TO     80.76               few clouds -21.2000
# 68           Harper      LR     77.32          overcast clouds   4.3750
# 70          Humaita      BR     75.11            broken clouds  -7.5061
# 72        Cartagena      CO     83.82         scattered clouds  10.3997
# 74            Praia      CV     77.54               few clouds  14.9215
# 75            Kapaa      US     84.18               light rain  22.0752
# 77         Bengkulu      ID     75.60               light rain  -3.8004
# 85            Arlit      NE     78.35                clear sky  18.7369
# 92             Daru      PG     84.70          overcast clouds  -9.0763
# 94          Aquiraz      BR     81.18               few clouds  -3.9014
# 96        Hithadhoo      MV     82.94               few clouds  -0.6000
# 104       Martapura      ID     87.89         scattered clouds  -3.4167
# 105         Lunglei      IN     73.49         scattered clouds  22.8833
# 113          Mattru      SL     73.63               light rain   7.6244
# 115       Caravelas      BR     76.71          overcast clouds -17.7125
# 117       Matamoros      MX     78.91                clear sky  25.5333
# 121          Maceio      BR     76.44                clear sky  -9.6658
# 123           Minab      IR     78.30                clear sky  27.1467
# 125         Isangel      VU     82.51            broken clouds -19.5500
# 126      Butaritari      KI     82.06                clear sky   3.0707
# 127        Ahuimanu      US     83.91            broken clouds  21.4447
# 128       Gushikawa      JP     80.19  light intensity drizzle  26.3544
# 132       Boa Vista      BR     84.18         scattered clouds   2.8197
# 133          Atuona      PF     78.13                clear sky  -9.8000
# 135          Touros      BR     79.70                clear sky  -5.1989
# 137         Mataura      NZ     71.17          overcast clouds -46.1927
# 141            Jalu      LY     70.36         scattered clouds  29.0331
# 143           Kutum      SD     70.92                clear sky  14.2000
#
#           Lng                                 Hotel Name
# 2    147.1797                Lamana Hotel (Port Moresby)
# 3    125.4092                             Juvinal Martin
# 8     57.6608       Veranda Paul et Virginie Hotel & Spa
# 10   -35.2086                          Rancho Crepusculo
# 13   -42.3664                        Premium Plaza Hotel
# 14    82.1500                            Hotel East Park
# 16  -134.9692                            People ThankYou
# 18  -159.7750                               Paradise Inn
# 19    31.6605                          Nile Palace Hotel
# 23   113.6333                      Hospitality Carnarvon
# 26  -151.7500         Bora-Bora Pearl Beach Resort & Spa
# 27   -97.5169                         Motel 6 Sinton, TX
# 31   -15.8333                         Casa Dora, Bubaque
# 33    57.5167                Shanti Maurice Resort & Spa
# 35    55.6167              "Plantation Bed and Breakfast
# 40  -155.0900                        Hilo Hawaiian Hotel
# 46   108.9000                                Mess P.Milu
# 53   -34.8339                              Hotel Pigalle
# 59   -65.3051                         Hotel Touring Club
# 60    55.7679               Chambres d'hôte "La Trinité"
# 61    77.2333                                 SVB Caters
# 63   -96.4661                      Hotel Posada San Jose
# 67  -175.2000                        Keleti Beach Resort
# 68    -7.7169                                Screensaver
# 70   -63.0208                               Corrêa Hotel
# 72   -75.5144            Hotel Colombia Real - Cartagena
# 74   -23.5087                              LT Aparthotel
# 75  -159.3190        Sheraton Kauai Coconut Beach Resort
# 77   102.2655                       Grage Hotel Bengkulu
# 85     7.3853           Case de Passage De la Prefecture
# 92   143.2092                                 Daru Lodge
# 94   -38.3911                      Pousada Rua Camurupim
# 96    73.0833                          Scoop Guest House
# 104  114.8500                      Montana Hotel Syariah
# 105   92.7333                                Hotel Elite
# 113  -11.8332  Mondkor Town, Bagbo Chiefdom, Bo District
# 115  -39.2481                     Pousada dos Navegantes
# 117 -103.2500                               Quinta Belem
# 121  -35.7353                             Poutur Pousada
# 123   57.0801                             Bam campground
# 125  169.2667                                Tanna Lodge
# 126  172.7902                         Isles Sunset Lodge
# 127 -157.8378                        Paradise Bay Resort
# 128  127.8686                         Kirari Guest House
# 132  -60.6733                         Aipana Plaza Hotel
# 133 -139.0333                                Villa Enata
# 135  -35.4608                            INN NEW HORIZON
# 137  168.8643                              Ellie's Villa
# 141   21.5482                              صاحبة الفخامة
# 143   24.6667                        Dibbo areaمنطقة دبو

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)


fig
# 11b. Display the figure
# Out:
# Figure(layout=FigureLayout(height='420px'))
